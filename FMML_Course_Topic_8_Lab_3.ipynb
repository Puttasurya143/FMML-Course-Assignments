# %% [markdown]
# <a href="https://colab.research.google.com/github/Puttasurya143/FMML-Course-Assignments/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-20 18:36:15--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  53.5MB/s    in 1.3s
#
# 2024-04-20 18:36:20 (53.5 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 11708  1610.03774v2  This work characterizes the benefits of averag...  stat
# 20085   1407.7184v1  Expectation is a central notion in probability...    cs
# 34532  1702.00956v2  Korea University Intelligent Signal Processing...    cs
# 16664  1704.08390v1  This paper describes the Duluth system that pa...    cs
# 846    1801.06597v1  Multi-view networks are ubiquitous in real-wor...    cs
# ...             ...                                                ...   ...
# 6121   1607.08194v4  Convolutional neural networks (CNN) have led t...  stat
# 38804   1309.4151v1  A new image denoising algorithm to deal with t...  stat
# 11801  1701.08055v1  Prediction and modelling of competitive sports...  stat
# 35469   0705.1110v1  In many applications it will be useful to know...    cs
# 2921   1704.04133v2  In this work, we propose CLass-Enhanced Attent...    cs
#
#                                                    title  year  \
# 11708  Parallelizing Stochastic Approximation Through...  2016
# 20085                        Reasoning about Expectation  2014
# 34532  KU-ISPL Speaker Recognition Systems under Lang...  2017
# 16664  Duluth at SemEval-2017 Task 6: Language Models...  2017
# 846    mvn2vec: Preservation and Collaboration in Mul...  2018
# ...                                                  ...   ...
# 6121   Convolutional Neural Networks Analyzed via Con...  2016
# 38804  A Non-Local Means Filter for Removing the Pois...  2013
# 11801  Modelling Competitive Sports: Bradley-Terry-Él...  2017
# 35469           Mining Patterns with a Balanced Interval  2007
# 2921   Explaining the Unexplained: A CLass-Enhanced A...  2017
#
#                                                 keywords
# 11708  [characterizes, averaging, techniques, conjunc...
# 20085  [expectation, probability, expectation, uncert...
# 34532  [university, intelligent, processing, develope...
# 16664  [describes, participated, hashtagwars, partici...
# 846    [ubiquitous, applications, knowledge, transfor...
# ...                                                  ...
# 6121   [convolutional, theoretical, understanding, al...
# 38804  [denoising, algorithm, establish, effectively,...
# 11801  [prediction, modelling, competitive, attention...
# 35469  [applications, combination, occurrences, occur...
# 2921   [attentive, visualize, understand, decisions, ...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 11708    [characterizes, averaging, techniques, conjunc...
# 20085    [expectation, probability, expectation, uncert...
# 34532    [university, intelligent, processing, develope...
# 16664    [describes, participated, hashtagwars, partici...
# 846      [ubiquitous, applications, knowledge, transfor...
#                                ...
# 11981    [variational, inference, approximate, posterio...
# 11577    [riemannian, dimensional, propagation, express...
# 30611    [preserving, framework, resolution, detection,...
# 22521    [introduce, durations, likelihood, inference, ...
# 10417    [empirical, statistical, importance, distribut...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8880 words.
# Out of those 4562 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7bc1655d-af28-4e40-9be5-5ed14f6ae012" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7bc1655d-af28-4e40-9be5-5ed14f6ae012")) {                    Plotly.newPlot(                        "7bc1655d-af28-4e40-9be5-5ed14f6ae012",                        [{"x":["establishes","operators","stepsizes","significantly","particular","characterize","characterizes","regression","parallelization","algorithm","parallelizable","providing","computational","generalizing","fundamental","involving","parallelizing","dependent","approximation","averaging","statistical","conjunction","properties","analyzing","differences","asymptotic","stochastic","generalization","developing","techniques","furthermore","introduced","uncertainty","semantics","underlying","representation","introduce","axiomatizations","functions","propositional","probability","expectation","satisfiability","reasoning","likelihood","expressive","corresponding","possibility","university","clustering","recognition","condition","unsupervised","experiments","investigated","compensate","development","discrepancy","developed","preliminary","intelligent","compensation","processing","compensating","collected","approaches","variability","evaluation","different","normalization","languages","mismatched","detection","participated","discusses","describes","demonstrate","effective","transform","knowledge","distributed","actionable","importance","ubiquitous","important","synthetic","therefore","feasibility","representations","preservation","collaboration","complicating","supervision","embedding","simultaneously","requiring","algorithms","characteristics","applications","motivated","achieving","meanwhile","additional","annotators","detecting","assessment","systematic","alternative","outperform","integrated","framework","comparable","bidirectional","participants","performance","compositional","architectures","comparison","piecewise","compressive","estimator","iteratively","performed","inversion","reconstruction","thresholding","available","implemented","represented","constituting","utilizing","compression","bandwidth","simulation","projection","measurement","contribution","extensive","eigenvalue","segmentations","recurrent","segmented","probabilistic","resorting","probabilities","programming","quantitative","meaningful","application","segmentation","respective","structure","efficient","sequences","segmental","computations","calculated","classification","digitized","mammograms","efficiency","specificity","classifying","mammographic","characterizing","malignant","mammogram","radiologists","effectiveness","neighbour","objective","promising","interpreted","experimental","iterative","recovered","expensive","computationally","redundant","combining","convolutional","preserves","challenge","transforms","multilayer","expansion","convolved","directional","observation","framelets","connected","benchmarks","simplicity","supplementary","scenarios","including","interactive","trajectory","parameterizations","competitive"],"y":[12,52,1,271,269,44,6,103,3,835,5,97,269,16,78,46,0,61,142,20,164,23,217,60,53,20,134,97,53,396,156,142,86,105,120,366,352,2,207,23,158,42,14,124,69,34,132,38,19,153,370,49,148,623,57,13,142,11,223,49,54,8,302,2,72,438,32,237,738,31,109,3,364,9,33,99,576,242,74,361,103,3,90,17,363,139,137,26,247,16,5,2,49,111,93,48,568,91,455,59,74,23,126,11,78,41,44,93,113,47,559,78,33,17,892,22,121,137,9,16,24,35,117,5,98,20,296,84,68,4,53,47,12,74,49,37,74,194,6,10,137,23,171,7,56,122,75,38,242,204,18,322,392,94,2,35,21,513,2,5,159,13,32,4,16,4,3,3,203,8,167,124,20,377,80,11,71,76,17,98,399,12,138,18,14,17,1,15,54,0,77,93,22,7,94,238,44,28,1,123],"type":"bar"},{"x":["establishes","operators","stepsize ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4562,), (4562, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7833333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.5967078189300412);'>Automatic</span> <span style=''>Document</span> <span style=''>Image</span> <span style='background-color:rgba(0, 255, 0, 0.8181818181818181);'>Binarization</span> <span style=''>using</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <br/><br/><span style=''>Document</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.8181818181818181);'>binarization</span> <span style=''>is</span> <span style=''>often</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.43076923076923074);'>challenging</span> <span style=''>task</span> <span style=''>due</span> <span style=''>to</span> <span style=''>various</span> <span style=''>forms</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.6363636363636364);'>degradation</span> <span style=''>Although</span> <span style=''>there</span> <span style=''>exist</span> <span style=''>several</span> <span style='background-color:rgba(0, 255, 0, 0.8181818181818181);'>binarization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>literature</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333326);'>binarized</span> <span style=''>image</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>typically</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sensitive</span> <span style=''>to</span> <span style=''>control</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style=''>settings</span> <span style=''>of</span> <span style=''>the</span> <span style=''>employed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.5967078189300412);'>automatic</span> <span style=''>document</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.8181818181818181);'>binarization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style=''>segment</span> <span style=''>the</span> <span style=''>text</span> <span style=''>from</span> <span style=''>heavily</span> <span style=''>degraded</span> <span style=''>document</span> <span style=''>images</span> <span style=''>The</span> <span style=''>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>uses</span> <span style=''>a</span> <span style=''>two</span> <span style=''>band</span> <span style=''>pass</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>filtering</span> <span style=''>approach</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.8117647058823529);'>background</span> <span style=''>noise</span> <span style=''>removal</span> <span style=''>and</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.5967078189300412);'>automatic</span> <span style='background-color:rgba(255, 0, 0, 0.47826086956521746);'>hyperparameter</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>for</span> <span style=''>optimal</span> <span style=''>results</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>effectiveness</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.8181818181818181);'>binarization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>is</span> <span style='background-color: ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>High</span> <span style=''>Order</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style=''>Gradient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Thermostats</span> <span style=''>for</span> <span style=''>Bayesian</span> <span style=''>Learning</span> <span style=''>of</span> <span style=''>Deep</span> <span style=''>Models</span> <br/><br/><span style=''>Learning</span> <span style=''>in</span> <span style=''>deep</span> <span style=''>models</span> <span style=''>using</span> <span style=''>Bayesian</span> <span style=''>methods</span> <span style=''>has</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attention</span> <span style=''>recently</span> <span style=''>This</span> <span style=''>is</span> <span style=''>largely</span> <span style=''>because</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>feasibility</span> <span style=''>of</span> <span style=''>modern</span> <span style=''>Bayesian</span> <span style=''>methods</span> <span style=''>to</span> <span style=''>yield</span> <span style=''>scalable</span> <span style=''>learning</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>while</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maintaining</span> <span style=''>a</span> <span style=''>measure</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>uncertainty</span> <span style=''>in</span> <span style=''>the</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style=''>gradient</span> <span style=''>MCMC</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>(SG</span> <span style=''>MCMC)</span> <span style=''>are</span> <span style=''>a</span> <span style=''>family</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>diffusion</span> <span style=''>based</span> <span style=''>sampling</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>Bayesian</span> <span style=''>learning</span> <span style=''>In</span> <span style=''>SG</span> <span style=''>MCMC</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>gradient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>thermostats</span> <span style=''>(mSGNHT)</span> <span style=''>augment</span> <span style=''>each</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>with</span> <span style=''>a</span> <span style=''>momentum</span> <span style=''>and</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>thermostat</span> <span style=''>variable</span> <span style=''>to</span> <span style=''>maintain</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stationary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>as</span> <span style=''>target</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>As</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>time</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Efficient</span> <span style=''>MRF</span> <span style=''>Energy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Minimization</span> <span style=''>via</span> <span style=''>Adaptive</span> <span style='background-color:rgba(255, 0, 0, 0.5000000000000001);'>Diminishing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Smoothing</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.40229885057471254);'>programming</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relaxation</span> <span style=''>of</span> <span style=''>an</span> <span style=''>energy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>problem</span> <span style=''>for</span> <span style=''>Markov</span> <span style=''>Random</span> <span style=''>Fields</span> <span style=''>The</span> <span style=''>dual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>of</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>can</span> <span style=''>be</span> <span style=''>treated</span> <span style=''>as</span> <span style=''>a</span> <span style=''>concave</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.4814814814814814);'>unconstrained</span> <span style=''>but</span> <span style=''>non</span> <span style=''>smooth</span> <span style=''>function</span> <span style=''>The</span> <span style=''>idea</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>smoothing</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>prior</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>was</span> <span style=''>recently</span> <span style=''>proposed</span> <span style=''>in</span> <span style=''>a</span> <span style=''>series</span> <span style=''>of</span> <span style=''>papers</span> <span style=''>Some</span> <span style=''>of</span> <span style=''>them</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>suggested</span> <span style=''>the</span> <span style=''>idea</span> <span style=''>to</span> <span style=''>decrease</span> <span style=''>the</span> <span style=''>amount</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>smoothing</span> <span style=''>(so</span> <span style=''>called</span> <span style=''>temperature)</span> <span style=''>while</span> <span style=''>getting</span> <span style=''>closer</span> <span style=''>to</span> <span style=''>the</span> <span style=''>optimum</span> <span style=''>However</span> <span style=''>no</span> <span style='background-color:rgba(255, 0, 0, 0.3388773388773389);'>theoretical</span> <span style=''>substantiation</span> <span style=''>was</span> <span style=''>provided</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>an</span> <span style=''>adaptive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>smoothing</span> <span style='background-color:rgba(255, 0, 0, 0.5000000000000001);'>diminishing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>duality</span> <span style=''>gap</span> <span style=''>between</span> <span style=''>relaxed</span> <span style=''>primal</span> <span style=''>and</span> <span style=''>dual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objectives</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiency</span> <span style=''>of</span> <span style=''>our</spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>Filter</span> <span style=''>Bank</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Sparsifying</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Transforms</span> <br/><br/><span style=''>Data</span> <span style=''>is</span> <span style=''>said</span> <span style=''>to</span> <span style=''>follow</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transform</span> <span style=''>(or</span> <span style=''>analysis)</span> <span style=''>sparsity</span> <span style=''>model</span> <span style=''>if</span> <span style=''>it</span> <span style=''>becomes</span> <span style=''>sparse</span> <span style=''>when</span> <span style=''>acted</span> <span style=''>on</span> <span style=''>by</span> <span style=''>a</span> <span style=''>linear</span> <span style=''>operator</span> <span style=''>called</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sparsifying</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transform</span> <span style=''>Several</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>have</span> <span style=''>been</span> <span style=''>designed</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>such</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transform</span> <span style=''>directly</span> <span style=''>from</span> <span style=''>data</span> <span style=''>and</span> <span style=''>data</span> <span style=''>adaptive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sparsifying</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transforms</span> <span style=''>have</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>excellent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>in</span> <span style=''>signal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>restoration</span> <span style=''>tasks</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Sparsifying</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transforms</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>typically</span> <span style=''>learned</span> <span style=''>using</span> <span style=''>small</span> <span style=''>sub</span> <span style=''>regions</span> <span style=''>of</span> <span style=''>data</span> <span style=''>called</span> <span style=''>patches</span> <span style=''>but</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>often</span> <span style=''>ignore</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>redundant</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>shared</span> <span style=''>between</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>neighboring</span> <span style=''>patches</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>many</span> <span style=''>existing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transform</span> <span style=''>and</span> <span style=''>analysis</span> <span style=''>sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>can</span> <span style=''>be</span> <span style=''>viewed</span> <span style=''>as</span> <span style=''>filter</span> <span style=''>banks</span> <span style=''>thus</span> <span style=''>linking</span> <span style=''>the</span> <span style=''>local</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>patch</span> <span style=''>based</span> <span style=''>model</span> <span style=''>to</span> <span style=''>the</span> <sp ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08239038189533239)
# 	representation (0.12942008486562942)
# 	knowledge (0.12765205091937765)
# 	processing (0.10678925035360678)
# 	information (0.24045261669024046)
# 	segmentation (0.07213578500707214)
# 	different (0.260961810466761)
# 	detection (0.12871287128712872)
# 	recognition (0.13083451202263083)
# 	convolutional (0.14108910891089108)
#
# Some Statistics words are:
# 	numerical (0.11967545638945233)
# 	stochastic (0.13995943204868155)
# 	distribution (0.18356997971602435)
# 	theoretical (0.16328600405679514)
# 	statistical (0.1678498985801217)
# 	inference (0.19776876267748478)
# 	estimation (0.18661257606490872)
# 	algorithm (0.41379310344827586)
# 	dimensional (0.19878296146044624)
# 	regression (0.18002028397565922)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0c720e79-2504-4aac-9bee-3e7d0a91a9d5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0c720e79-2504-4aac-9bee-3e7d0a91a9d5")) {                    Plotly.newPlot(                        "0c720e79-2504-4aac-9bee-3e7d0a91a9d5",                        [{"x":["establishes","operators","stepsizes","significantly","particular","characterize","characterizes","regression","parallelization","algorithm","parallelizable","providing","computational","generalizing","fundamental","involving","parallelizing","dependent","approximation","averaging","statistical","conjunction","properties","analyzing","differences","asymptotic","stochastic","generalization","developing","techniques","furthermore","introduced","uncertainty","semantics","underlying","representation","introduce","axiomatizations","functions","propositional","probability","expectation","satisfiability","reasoning","likelihood","expressive","corresponding","possibility","university","clustering","recognition","condition","unsupervised","experiments","investigated","compensate","development","discrepancy","developed","preliminary","intelligent","compensation","processing","compensating","collected","approaches","variability","evaluation","different","normalization","languages","mismatched","detection","participated","discusses","describes","demonstrate","effective","transform","knowledge","distributed","actionable","importance","ubiquitous","important","synthetic","therefore","feasibility","representations","preservation","collaboration","complicating","supervision","embedding","simultaneously","requiring","algorithms","characteristics","applications","motivated","achieving","meanwhile","additional","annotators","detecting","assessment","systematic","alternative","outperform","integrated","framework","comparable","bidirectional","participants","performance","compositional","architectures","comparison","piecewise","compressive","estimator","iteratively","performed","inversion","reconstruction","thresholding","available","implemented","represented","constituting","utilizing","compression","bandwidth","simulation","projection","measurement","contribution","extensive","eigenvalue","segmentations","recurrent","segmented","probabilistic","resorting","probabilities","programming","quantitative","meaningful","application","segmentation","respective","structure","efficient","sequences","segmental","computations","calculated","classification","digitized","mammograms","efficiency","specificity","classifying","mammographic","characterizing","malignant","mammogram","radiologists","effectiveness","neighbour","objective","promising","interpreted","experimental","iterative","recovered","expensive","computationally","redundant","combining","convolutional","preserves","challenge","transforms","multilayer","expansion","convolved","directional","observation","framelets","connected","benchmarks","simplicity","supplementary","scenarios","including","interactive","trajectory","parameterizations","competitive","perturbations","continuous","elaborate","distribution","population","communicative","numerical","simulations","agreement","essentially","strategies","artificial","minimizes","alignment","dimensional","linguistic","vocabularies","formation","vocabulary","relations","conventions","principle","communities","emergence","individuals","selection","arrhythmias","necessity","extracted","heartbeat","consisting","eliminate","procedures","automated","electrocardiogram","interpretation","heartbeats","morphological","literature","extraction","parametric","following","cardiologists","sufficient","practicing","complexity","constructing","intelligently","convergence","sequentially","depending","information" ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	parallelizing
# 	framelets
# 	heartbeat
# 	heartbeats
# 	practicing
# 	propensity
# 	subgaussian
# 	continuing
# 	trivially
# 	prominently
# 	transports
# 	emphasizing
# 	regressions
# 	executable
# 	diffusing
# 	microarrays
# 	dendrogram
# 	misspecified
# 	phenotypes
# 	unavoidably
# Some words which never appear in Statistics papers:
# 	axiomatizations
# 	propositional
# 	compensate
# 	compensation
# 	complicating
# 	digitized
# 	mammograms
# 	mammographic
# 	mammogram
# 	radiologists
# 	communicative
# 	conventions
# 	omniscient
# 	extraordinary
# 	reachability
# 	traveling
# 	categorizes
# 	reflexive
# 	polyhedron
# 	microphone

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0448815541075455e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7525
